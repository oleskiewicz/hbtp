# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit
    
from src import nfw
from src import einasto

# %%
c = 7.0

# %%
def chi2(f, xs, ys):
    return [np.sum(np.power((ys - f(x)), 2.0)) for x in xs]

# %%
def fit(f, xs, ys):
    """chi2 fit.
    """    
    chi2 = chi2(f, xs, ys)
    i = np.argmin(chi2)
    return xs[i], chi2[i]

# %%
n = 20
x = np.linspace(-2.0, 0.0, n)
# y = np.log10(nfw.m_diff(np.power(10.0, x), c))[1:]
# y = (1.0 + 0.2*np.random.random(len(y)))*y
# x = x[1:]

# %%
def f(x, c):
    return np.log10(nfw.m_diff(np.power(10.0, x), c))

c_fit = curve_fit(f, x, p)[0][0]

# %%
c_fit
# Out:
# 6.9741014706781561

# %%
plt.plot(
    x, p, 'o',
    x, f(x, c_fit), 'r',
    x, f(x, 7.943282347242816), 'g')

# %%
plt.plot(x, y, 'o',
         x, f(x, c_ein[0])
)
